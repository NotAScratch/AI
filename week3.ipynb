# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('salary.csv')

# %%
df
# Out:
#     Experience Years  Salary
# 0                1.1   39343
# 1                1.2   42774
# 2                1.3   46205
# 3                1.5   37731
# 4                2.0   43525
# 5                2.2   39891
# 6                2.5   48266
# 7                2.9   56642
# 8                3.0   60150
# 9                3.2   54445
# 10               3.2   64445
# 11               3.5   60000
# 12               3.7   57189
# 13               3.8   60200
# 14               3.9   63218
# 15               4.0   55794
# 16               4.0   56957
# 17               4.1   57081
# 18               4.3   59095
# 19               4.5   61111
# 20               4.7   64500
# 21               4.9   67938
# 22               5.1   66029
# 23               5.3   83088
# 24               5.5   82200
# 25               5.9   81363
# 26               6.0   93940
# 27               6.2   91000
# 28               6.5   90000
# 29               6.8   91738
# 30               7.1   98273
# 31               7.9  101302
# 32               8.2  113812
# 33               8.5  111620
# 34               8.7  109431
# 35               9.0  105582
# 36               9.5  116969
# 37               9.6  112635
# 38              10.3  122391
# 39              10.5  121872

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 772.0 bytes

# %%
df.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['Experience Years'], df['Salary'])

# %%
x = df[['Experience Years']]
y = df[['Salary']]

# %%
import sklearn as sk
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# array([27236.21125393])

# %%
model.coef_
# Out:
# array([[9210.7373577]])

# %%
y_pred = model.predict(x_test)

# %%
compare = pd.DataFrame({'Actual': y_test.values.flatten(), 'Predicted': y_pred.flatten()})

# %%
compare
# Out:
#    Actual      Predicted
# 0   64500   70526.676835
# 1  112635  115659.289888
# 2   60200   62237.013213
# 3   93940   82500.635400
# 4   57081   65000.234420
# 5  111620  105527.478794
# 6  113812  102764.257587
# 7   39891   47499.833441

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mse
# Out:
# np.float64(57531961.93519239)

# %%
r2
# Out:
# 0.9251051162654998

# %%
plt.scatter(x, y, color='black')
plt.plot(x_test, y_pred, color='blue', linewidth=3)
plt.show()
